# %%
# %load_ext autoreload
# %autoreload 2
from mildetector.openpose import OpenPose

# %% [markdown]
# # Export CSV

# %%
op = OpenPose(runenv='jupyter', binpath='/opt/software/bin', debug=False)
op.auto_export_from_dir(videosdir='/home/jkado/shared/dataset/baseball/pitch-types/', extension='.mp4')
# Out:
# start to get data from openpose....
# processing... 0/55
# WARNING:root:Empty frame was detected. Update frame number from 107 to 78
# processing... 1/55
# WARNING:root:Empty frame was detected. Update frame number from 84 to 55
# processing... 2/55
# WARNING:root:Empty frame was detected. Update frame number from 96 to 67
# processing... 3/55
# WARNING:root:Empty frame was detected. Update frame number from 90 to 60
# processing... 4/55
# WARNING:root:Empty frame was detected. Update frame number from 82 to 53
# processing... 5/55
# WARNING:root:Empty frame was detected. Update frame number from 93 to 64
# processing... 6/55
# WARNING:root:Empty frame was detected. Update frame number from 108 to 79
# processing... 7/55
# WARNING:root:Empty frame was detected. Update frame number from 110 to 81
# processing... 8/55
# WARNING:root:Empty frame was detected. Update frame number from 99 to 70
# processing... 9/55
# WARNING:root:Empty frame was detected. Update frame number from 124 to 95
# processing... 10/55
# WARNING:root:Empty frame was detected. Update frame number from 87 to 58
# processing... 11/55
# WARNING:root:Empty frame was detected. Update frame number from 87 to 58
# processing... 12/55
# WARNING:root:Empty frame was detected. Update frame number from 96 to 67
# processing... 13/55
# WARNING:root:Empty frame was detected. Update frame number from 105 to 76
# processing... 14/55
# WARNING:root:Empty frame was detected. Update frame number from 88 to 59
# processing... 15/55
# WARNING:root:Empty frame was detected. Update frame number from 104 to 75
# processing... 16/55
# WARNING:root:Empty frame was detected. Update frame number from 119 to 90
# processing... 17/55
# WARNING:root:Empty frame was detected. Update frame number from 118 to 89
# processing... 18/55
# WARNING:root:Empty frame was detected. Update frame number from 115 to 86
# processing... 19/55
# WARNING:root:Empty frame was detected. Update frame number from 106 to 77
# processing... 20/55
# WARNING:root:Empty frame was detected. Update frame number from 108 to 79
# processing... 21/55
# WARNING:root:Empty frame was detected. Update frame number from 131 to 102
# processing... 22/55
# WARNING:root:Empty frame was detected. Update frame number from 109 to 80
# processing... 23/55
# WARNING:root:Empty frame was detected. Update frame number from 109 to 80
# processing... 24/55
# WARNING:root:Empty frame was detected. Update frame number from 118 to 89
# processing... 25/55
# WARNING:root:Empty frame was detected. Update frame number from 108 to 79
# processing... 26/55
# WARNING:root:Empty frame was detected. Update frame number from 139 to 110
# processing... 27/55
# WARNING:root:Empty frame was detected. Update frame number from 85 to 56
# processing... 28/55
# WARNING:root:Empty frame was detected. Update frame number from 100 to 71
# processing... 29/55
# WARNING:root:Empty frame was detected. Update frame number from 136 to 107
# processing... 30/55
# WARNING:root:Empty frame was detected. Update frame number from 103 to 74
# processing... 31/55
# WARNING:root:Empty frame was detected. Update frame number from 132 to 103
# processing... 32/55
# WARNING:root:Empty frame was detected. Update frame number from 87 to 58
# processing... 33/55
# WARNING:root:Empty frame was detected. Update frame number from 87 to 58
# processing... 34/55
# WARNING:root:Empty frame was detected. Update frame number from 115 to 86
# processing... 35/55
# WARNING:root:Empty frame was detected. Update frame number from 135 to 106
# processing... 36/55
# WARNING:root:Empty frame was detected. Update frame number from 107 to 78
# processing... 37/55
# WARNING:root:Empty frame was detected. Update frame number from 110 to 81
# processing... 38/55
# WARNING:root:Empty frame was detected. Update frame number from 115 to 86
# processing... 39/55
# WARNING:root:Empty frame was detected. Update frame number from 103 to 74
# Select id
# <PIL.Image.Image image mode=RGB size=1080x960 at 0x7F68224188D0>
#  0
# processing... 40/55
# WARNING:root:Empty frame was detected. Update frame number from 99 to 70
# processing... 41/55
# WARNING:root:Empty frame was detected. Update frame number from 111 to 82
# processing... 42/55
# WARNING:root:Empty frame was detected. Update frame number from 106 to 77
# processing... 43/55
# WARNING:root:Empty frame was detected. Update frame number from 98 to 69
# processing... 44/55
# WARNING:root:Empty frame was detected. Update frame number from 89 to 60
# processing... 45/55
# WARNING:root:Empty frame was detected. Update frame number from 109 to 80
# processing... 46/55
# WARNING:root:Empty frame was detected. Update frame number from 99 to 70
# processing... 47/55
# WARNING:root:Empty frame was detected. Update frame number from 86 to 57
# processing... 48/55
# WARNING:root:Empty frame was detected. Update frame number from 124 to 95
# processing... 49/55
# WARNING:root:Empty frame was detected. Update frame number from 107 to 78
# processing... 50/55
# WARNING:root:Empty frame was detected. Update frame number from 114 to 85
# processing... 51/55
# WARNING:root:Empty frame was detected. Update frame number from 91 to 62
# processing... 52/55
# WARNING:root:Empty frame was detected. Update frame number from 97 to 68
# processing... 53/55
# WARNING:root:Empty frame was detected. Update frame number from 118 to 89
# processing... 54/55
# WARNING:root:Empty frame was detected. Update frame number from 92 to 63
# finish getting data!
# saved csv data in 2d-data directory

# %% [markdown]
# # Debug for several functions

# %%
op = OpenPose(runenv='jupyter', binpath='/opt/software/bin', debug=True)
op.parse_video("/home/jkado/shared/dataset/baseball/pitch-types/Pitch_01_joined_p4_1.mp4")
#op.run_openpose()
op.json2csv()
#op.manual_videofile("/home/jkado/shared/dataset/baseball/pitch-types/Pitch_01_joined_p4_1.mp4")
# Out:
# WARNING:root:Empty frame was detected. Update frame number from 107 to 63
# Output(layout=Layout(border='1px solid black'))
# aaa
# <video controls>
#  <source src="data:mp4;base64,..." type="mp4">
#  Your browser does not support the video tag.
#  </video>

# %% [markdown]
# # Debug for auto selection

# %%
op = OpenPose(runenv='jupyter', binpath='/opt/software/bin', debug=False)
op.auto_export_from_dir(extension='.mp4')
# Out:
# start to get data from openpose....
# processing... 0/2
# WARNING:root:Empty frame was detected. Update frame number from 107 to 78
# processing... 1/2
# WARNING:root:Empty frame was detected. Update frame number from 84 to 55
# finish getting data!
# saved csv data in 2d-data directory

# %% [markdown]
# # Debug for manual selection

# %%
op.manual_export_from_file("/home/jkado/test/IMG_8761.MOV")
# Out:
# Select id
# <PIL.Image.Image image mode=RGB size=1080x960 at 0x7F68224337B8>
#  0

# %%
from IPython.display import Video, display, HTML
display(Video("/home/jkado/program/machine-learning/mildetector/video/Pitch_01_joined_p4_1.mp4", embed=True, mimetype='mp4'))
# Out:
# <video controls>
#  <source src="data:mp4;base64,..." type="mp4">
#  Your browser does not support the video tag.
#  </video>

# %%
HTML("""
    <video alt="test" controls>
        <source src="/home/jkado/program/machine-learning/mildetector/video/Pitch_01_joined_p4_1.mp4" type="video/mp4">
    </video>
""")
# Out:
#     <video alt="test" controls>
#         <source src="/home/jkado/program/machine-learning/mildetector/video/Pitch_01_joined_p4_1.mp4" type="video/mp4">
#     </video>
